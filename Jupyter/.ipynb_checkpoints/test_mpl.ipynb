# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
plt.xlabel('score')
plt.ylabel('grade')
plt.show()

# %%
x = np.arange(3)

plt.bar(x, [100, 400, 900])
plt.xticks(x, ['2018', '2019', '2020'])

plt.show()
